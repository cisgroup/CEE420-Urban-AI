# %% [markdown]
# # P01 environment check
#
# Welcome to CEE420 Urban AI. This notebook has one job: proving that your environment works.
#
# **Click "Run All" in the toolbar above.** If VS Code asks for a kernel, pick **Urban AI (Python 3.12)**.
#
# Your environment is set up when Princeton appears.

# %%
import platform
import sys

import folium
import geopandas as gpd
import mapclassify
import matplotlib
import osmnx

print(f"python     {sys.version.split()[0]} on {platform.machine()}")
print(f"geopandas  {gpd.__version__}")
print(f"osmnx      {osmnx.__version__}")
print(f"folium     {folium.__version__}")
print(f"matplotlib {matplotlib.__version__}")

# %%
boundary = gpd.read_file("data/princeton_boundary.geojson")
ax = boundary.plot(figsize=(6, 6), color="#f5f0e6", edgecolor="#e77500", linewidth=2)
ax.set_title("Princeton, New Jersey")
ax.set_axis_off()
print("\u2705 READY, your environment works. See you Wednesday.")

# %% [markdown]
# **Did the map not appear?** Two minutes of trying, then switch lanes: open this repository in a
# GitHub Codespace instead (see `docs/setup-codespaces.md`) and fix your local install later at the
# install clinic. Nobody debugs installs during class.
